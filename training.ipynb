# %%
import torch 
import pandas as pd 
import torch.optim as optim
from torch.utils.data import DataLoader
from data_preparation import *
from dataloader import *
from tensorconversion import *
from GAT_MLP_Network import *
from train_evaluate import *
from hyperparameters import *

# %%
train_df = pd.read_csv('Data/train.csv')
test_df = pd.read_csv('Data/test.csv')

# %%
print(len(train_df),len(test_df))
# Out:
# 6644 977

# %%
def preprocess(smiles,labels,batch_size=None,shuffle=None,generator=None):
    processor = MoleculeProcessor(smiles,labels)
    full_graph_batch = processor.node_edge_feature_extraction()
    fps = np.array(processor.calculate_fingerprint(radius=3,fpsize=4096))
    tensor_converter = TensorConversion()
    fps_data = tensor_converter.convert_to_tensor(fps)
    combined_dataset = SynchronizedDataset(full_graph_batch,fps_data)
    combined_dataloader = DataLoader(
    combined_dataset, 
    batch_size = batch_size,
    shuffle = shuffle,
    generator = generator, 
    collate_fn=collate_fn
    # generator=torch.Generator().manual_seed(42)
)
    return combined_dataloader

# %%
train_dataloader = preprocess(train_df['Smiles'],train_df['Label'],batch_size=64, shuffle=True, generator=torch.Generator().manual_seed(42))
# Out:
# 2026-03-24 13:02:37 - data_preparation.py:45 - _generate_molecules - Total valid SMILES found: 6644
# 2026-03-24 13:02:41 - tensorconversion.py:24 - convert_to_tensor - Converting fingerprint array to tensor. Shape: (6644, 4096)
# 2026-03-24 13:02:41 - tensorconversion.py:26 - convert_to_tensor - Converted tensor shape: torch.Size([6644, 4096])

# %%
test_dataloader = preprocess(test_df['Smiles'],test_df['Label'],batch_size=64)
# Out:
# 2026-03-24 13:02:42 - data_preparation.py:45 - _generate_molecules - Total valid SMILES found: 977
# 2026-03-24 13:02:43 - tensorconversion.py:24 - convert_to_tensor - Converting fingerprint array to tensor. Shape: (977, 4096)
# 2026-03-24 13:02:43 - tensorconversion.py:26 - convert_to_tensor - Converted tensor shape: torch.Size([977, 4096])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CombinedModelGATMLP(config.gnn_in_channels, config.gnn_hidden_channels, config.gnn_out_channels,
                      config.mlp_input_size, config.mlp_hidden_sizes, config.mlp_output_size, config.dense_size_1, config.dense_size_2).to(device)
criterion = torch.nn.BCEWithLogitsLoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=config.lr,weight_decay= config.weight_decay)

# %%
print(model)
# Out:
# CombinedModelGATMLP(
#   (gnn): GATModel(
#     (gat_conv): GATConv(9, 57, heads=1)
#     (lin): Linear(in_features=57, out_features=34, bias=True)
#   )
#   (mlp): MLPModel(
#     (mlp): Sequential(
#       (0): Linear(in_features=4096, out_features=2469, bias=True)
#       (1): BatchNorm1d(2469, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.17988426707538552, inplace=False)
#       (4): Linear(in_features=2469, out_features=185, bias=True)
#     )
#   )
#   (fc1): Linear(in_features=219, out_features=112, bias=True)
#   (batchnorm1): BatchNorm1d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (linear): Linear(in_features=112, out_features=1, bias=True)
# )

# %%
trainer = ModelTrainer(model,criterion,optimizer,device)
# Out:
# 2026-03-24 13:02:44 - train_evaluate.py:23 - __init__ -
# Model Architecture:
# ####################################################################################################
# # CombinedModelGATMLP(                                                                             #
# #   (gnn): GATModel(                                                                               #
# #     (gat_conv): GATConv(9, 57, heads=1)                                                          #
# #     (lin): Linear(in_features=57, out_features=34, bias=True)                                    #
# #   )                                                                                              #
# #   (mlp): MLPModel(                                                                               #
# #     (mlp): Sequential(                                                                           #
# #       (0): Linear(in_features=4096, out_features=2469, bias=True)                                #
# #       (1): BatchNorm1d(2469, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)     #
# #       (2): ReLU()                                                                                #
# #       (3): Dropout(p=0.17988426707538552, inplace=False)                                         #
# #       (4): Linear(in_features=2469, out_features=185, bias=True)                                 #
# #     )                                                                                            #
# #   )                                                                                              #
# #   (fc1): Linear(in_features=219, out_features=112, bias=True)                                    #
# #   (batchnorm1): BatchNorm1d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) #
# #   (dropout2): Dropout(p=0.3, inplace=False)                                                      #
# #   (linear): Linear(in_features=112, out_features=1, bias=True)                                   #
# # )                                                                                                #
# ####################################################################################################

# %%
best_model, train_losses, train_accuracies, final_true_labels, final_predicted_labels = trainer.train(train_dataloader)
# Out:
# Epoch 1, Loss: 0.5366, Accuracy: 0.7360
# Epoch 2, Loss: 0.4492, Accuracy: 0.7962
# Epoch 3, Loss: 0.4426, Accuracy: 0.7997
# Epoch 4, Loss: 0.4337, Accuracy: 0.8069
# Epoch 5, Loss: 0.4325, Accuracy: 0.8033
# Epoch 6, Loss: 0.4227, Accuracy: 0.8108
# Epoch 7, Loss: 0.4139, Accuracy: 0.8183
# Epoch 8, Loss: 0.4082, Accuracy: 0.8225
# Epoch 9, Loss: 0.4034, Accuracy: 0.8218
# Epoch 10, Loss: 0.3798, Accuracy: 0.8385
# Epoch 11, Loss: 0.3686, Accuracy: 0.8408
# Epoch 12, Loss: 0.3487, Accuracy: 0.8567
# Epoch 13, Loss: 0.3367, Accuracy: 0.8567
# Epoch 14, Loss: 0.3055, Accuracy: 0.8748
# Epoch 15, Loss: 0.2873, Accuracy: 0.8806
# Epoch 16, Loss: 0.2673, Accuracy: 0.8933
# Epoch 17, Loss: 0.2414, Accuracy: 0.9061
# Epoch 18, Loss: 0.2279, Accuracy: 0.9113
# Epoch 19, Loss: 0.2090, Accuracy: 0.9223
# Epoch 20, Loss: 0.1998, Accuracy: 0.9255
# Epoch 21, Loss: 0.1808, Accuracy: 0.9351
# Epoch 22, Loss: 0.1820, Accuracy: 0.9326
# Epoch 23, Loss: 0.1673, Accuracy: 0.9363
# Epoch 24, Loss: 0.1595, Accuracy: 0.9448
# Epoch 25, Loss: 0.1564, Accuracy: 0.9425
# Epoch 26, Loss: 0.1461, Accuracy: 0.9476
# Epoch 27, Loss: 0.1483, Accuracy: 0.9491
# Epoch 28, Loss: 0.1468, Accuracy: 0.9485
# Epoch 29, Loss: 0.1262, Accuracy: 0.9583
# Epoch 30, Loss: 0.1383, Accuracy: 0.9496
# Epoch 31, Loss: 0.1322, Accuracy: 0.9539
# Epoch 32, Loss: 0.1349, Accuracy: 0.9542
# Epoch 33, Loss: 0.1350, Accuracy: 0.9559
# Epoch 34, Loss: 0.1348, Accuracy: 0.9529
# Epoch 35, Loss: 0.1295, Accuracy: 0.9542
# Epoch 36, Loss: 0.1392, Accuracy: 0.9506
# Epoch 37, Loss: 0.1400, Accuracy: 0.9490
# Epoch 38, Loss: 0.1253, Accuracy: 0.9553
# 2026-03-24 13:03:56 - train_evaluate.py:106 - train - Training Completed.
# #####################################
# # Loss: 0.1262 and Accuracy: 0.9583 #
# #####################################
# Epoch 39, Loss: 0.1269, Accuracy: 0.9551
#
# Early stopping triggered. Best loss: 0.1262
#
# Final Results:
# Accuracy: 0.9583
# Precision: 0.9579
# Recall: 0.9559
# Specificity for class_0: 0.9559
# Specificity for class_1: 0.9606
# F1 Score: 0.9569
# Confusion Matrix:
# [[3292  135]
#  [ 142 3075]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class_0       0.96      0.96      0.96      3427
#      class_1       0.96      0.96      0.96      3217
#
#     accuracy                           0.96      6644
#    macro avg       0.96      0.96      0.96      6644
# weighted avg       0.96      0.96      0.96      6644

# %%
all_probs,all_preds, all_targets,avg_loss, accuracy, conf_matrix, class_report, roc_auc, fpr, tpr = trainer.evaluate(best_model, test_dataloader)
# Out:
# 2026-03-24 13:04:03 - train_evaluate.py:152 - evaluate - Evaluation Completed.
# ###################################
# # Loss:0.5428 and Accuracy:0.8342 #
# ###################################
# 2026-03-24 13:04:03 - train_evaluate.py:153 - evaluate -
# Classification Report:
# #########################################################
# #               precision    recall  f1-score   support #
# #                                                       #
# #          0.0       0.82      0.79      0.81       426 #
# #          1.0       0.84      0.87      0.85       551 #
# #                                                       #
# #     accuracy                           0.83       977 #
# #    macro avg       0.83      0.83      0.83       977 #
# # weighted avg       0.83      0.83      0.83       977 #
# #                                                       #
# #########################################################
# Loss: 0.5428
# Accuracy: 0.8342
# [[338  88]
#  [ 74 477]]
# Specificity class_0 : 0.8657
# Specificity class_1 : 0.7934
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.79      0.81       426
#          1.0       0.84      0.87      0.85       551
#
#     accuracy                           0.83       977
#    macro avg       0.83      0.83      0.83       977
# weighted avg       0.83      0.83      0.83       977

# %%
# torch.save(best_model, 'Muta_MLP_best_model1.pth')
